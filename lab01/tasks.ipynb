# %% [markdown]
# # Задачи по теми 2 и 3

# %% [markdown]
# ## Задача X (0.5 т.)
#
# По дадена дата във формат `YYYY-MM-DD` (тип `str`) да се върне наредена тройка от числа (`int`), съответстващи на годината, месеца и деня.
#
# * Hint: може да използвате `str.split`

# %%
def extract_date_components(date_string):
    pass # your code here


# Tests:

assert extract_date_components('1970-01-01') == (1970, 1, 1)
assert extract_date_components('2023-10-22') == (2023, 10, 22)
assert extract_date_components('0000-12-25') == (0, 12, 25)
assert extract_date_components('2009-02-29') == (2009, 2, 29), "no one said it should be a valid date"

"✅ All OK! +0.5 points"

# %% [markdown]
# ## Задача X (0.5т.)
#
# Напишете функция `format_date_components`, която:
#
# * приема 3 позиционни параметъра: `year`, `month`, `day` (тип `int`)
# * приема 1 именуван параметър `separator` (тип `str`), по подразбиране със стойност `'-'`
# * връща `str` с годината, месеца и деня, разделени със `separator` символа
# * цифрите на месеца и деня да точно 2
#
# Number formatting reference: https://www.pythoncheatsheet.org/cheatsheet/string-formatting#formatting-digits

# %%
# write the function here


# Tests:

assert format_date_components(2023, 10, 22) == '2023-10-22'
assert format_date_components(2112, 12, 21, separator='/') == '2112/12/21'
assert format_date_components(1970, 1, 1) == '1970-01-01', "check your leading zeroes formatting!"
assert format_date_components(1, 12, 25) == '0001-12-25', "leading zeroes for the year as well!"

"✅ All OK! +0.5 points"

# %% [markdown]
# ## Задача X (0.5 т.)
#
# Изведете дадено количество `count` в "човеко-четим" (human-readable) формат.
#
# Нека това става по следните правила:
#
# *  Ако $ |count| $ е по-малък от 1000, върнете го непроменен.
# *  Ако $ |count| $ е между 1000 и 1 000 000, върнете само хилядите му с долепена буква `K` след тях (без закръгляне и дробни части).
# *  Ако $ |count| $ е между 1 000 000 и 1 000 000 000, върнете само милионите му с долепена буква `M` след тях (без закръгляне и дробни части).
# *  Аналогично за милиардите `B` и трилионите `T`.
# *  Числата по-големи от квадрилион нека не се променят.
#
#
# **Резултатът трябва винаги да е от тип `str`!**
#
# *Hint:* модул (абсолютна стойност) на `x` се взима с `abs(x)`.

# %%
def human_readable(count):
    pass # write your code here


# Tests:

assert human_readable(0) == '0'
assert human_readable(999) == '999'
assert human_readable(1_000) == '1K'
assert human_readable(1_999) == '1K'
assert human_readable(1_000_000) == '1M'
assert human_readable(666_999_666) == '666M'
assert human_readable(1_000_000_000) == '1B'
assert human_readable(1_234_567_890) == '1B'
assert human_readable(1_000_000_000_000) == '1T'
assert human_readable(-1) == '-1'
assert human_readable(-1000) == '-1K'

"✅ All OK! +0.5 points"

# %% [markdown]
# ## Задача X (0.5т.)
#
# Съединете двата `dict`-а в един.

# %%
def merge(d1, d2):
    pass # write your code here


# Tests:

assert merge({"name": "Pesho", "year": 1999}, {"groups": ["A", "B"]}) == {"name": "Pesho", "year": 1999, "groups": ["A", "B"]}
assert merge({}, {}) == {}

"✅ All OK! +0.5 points"

# %% [markdown]
# ## Задача X (0.5т.)
#
# Намерете броя на цифрите на дадено число (в десетична бройна система).

# %%
def digits_count(n):
    pass # your code here


# Tests:

assert digits_count(0) == 1
assert digits_count(1) == 1
assert digits_count(9) == 1
assert digits_count(10) == 2
assert digits_count(666) == 3
assert digits_count(1234) == 4
assert digits_count(9876543210) == 10
assert digits_count(31415926535897932384626433832795028841971693993751058209749445923078164062862089986280) == 86

"✅ All OK! +0.5 points"

# %% [markdown]
# ## Задача X (0.5т.)
#
# Пребройте колко различни символа има в даден низ.

# %%
def unique_chars_count(s):
    pass # your code here

# Tests:

assert unique_chars_count("abcdef") == 6
assert unique_chars_count("aabbcc") == 3
assert unique_chars_count("abcabc") == 3
assert unique_chars_count("aaaaaa") == 1
assert unique_chars_count("") == 0

"✅ All OK! +0.5 points"

# %% [markdown]
# ## Задача Y (0.5 т.)
#
# Иванчо наскоро започна работа като freelancer. Понеже заплатата му не е еднаква всеки месец, а той иска да управлява финансите си, на него му е необходима помощ, за да разбере как да разпредели парите си.
#
# Създайте функция manage_money, която:
# * Приема 1 позиционен параметър - заплатата на Иванчо
# * Връща наредена тройка, която се състои от:
#     * Парите, които Иванчо ще използва за битови разходи (50% от заплатата)
#     * Парите, които Иванчо може да похарчи (20% от заплата)
#     * Парите, които Иванчо ще трябва да вложи вложи за спестявания (30% от заплатата)

# %%
def manage_money(salary):
    pass # your code here


# Tests:

assert manage_money(1600) == (800, 320, 480)
assert manage_money(0) == (0, 0, 0)
assert manage_money(9152.65) == (4576.325, 1830.53, 2745.795)
assert manage_money(4853) == (2426.5, 970.6, 1455.9) 

"✅ All OK! +0.5 points"

# %% [markdown]
# ## Задача Y (0.5 т.)
#
# Създайте функция filter_names, която:
# * Приема 1 позиционен параметър - стринг от имена, разделени с интервал
# * Връща списък от тези имена, които са с дължина не по-малка от 4, но не по-голяма от 7.

# %%
def filter_names(names):
    pass # your code here


# Tests:

result = filter_names("Ivanka Petko Ana Maria Sebastian Ivo")
expected_result = ["Ivanka", "Petko", "Maria"]
assert len(result) == 3
assert all(name in result for name in expected_result)
assert len(filter_names("Ivo Ana Sebastian")) == 0

"✅ All OK! +0.5 points"

# %% [markdown]
# ## Задача X (1т.)
#
# Преобразувайте даден текст от кирилица в глаголица.

# %%
GLAGOLITIC_MAP = {
    "А": "Ⰰ",
    "Б": "Ⰱ",
    "В": "Ⰲ",
    "Г": "Ⰳ",
    "Д": "Ⰴ",
    "Е": "Ⰵ",
    "Ж": "Ⰶ",
    "З": "Ⰸ",
    "И": "Ⰻ",
    "Й": "Ⰺ",
    "К": "Ⰽ",
    "Л": "Ⰾ",
    "М": "Ⰿ",
    "Н": "Ⱀ",
    "О": "Ⱁ",
    "П": "Ⱂ",
    "Р": "Ⱃ",
    "С": "Ⱄ",
    "Т": "Ⱅ",
    "У": "Ⱆ",
    "Ф": "Ⱇ",
    "Х": "Ⱈ",
    "Ц": "Ⱌ",
    "Ч": "Ⱍ",
    "Ш": "Ⱎ",
    "Щ": "Ⱋ",
    "Ъ": "Ⱏ",
    "Ь": "Ⱐ",
    "Ю": "Ⱓ",
    "Я": "Ⱖ",
}

def to_glagolitic(cyrillic):
    pass # your code here


# Tests:

assert to_glagolitic("АБВГД") == "ⰀⰁⰂⰃⰄ"
assert to_glagolitic("абвгд") == "ⰀⰁⰂⰃⰄ", "handle lowercase input too!"
assert to_glagolitic("АбВгД") == "ⰀⰁⰂⰃⰄ", "handle mixed case input too!"
assert to_glagolitic("а.") == "Ⰰ.", "non-cyrrilic symbols should remain the same"
assert to_glagolitic("Вкъщи не яж сьомга с фиде без ракийка и хапка люта чушчица!") == "ⰂⰍⰟⰛⰋ ⰐⰅ ⰦⰆ ⰔⰠⰑⰏⰃⰀ Ⱄ ⰗⰋⰄⰅ ⰁⰅⰈ ⰓⰀⰍⰋⰊⰍⰀ Ⰻ ⰘⰀⰒⰍⰀ ⰎⰣⰕⰀ ⰝⰖⰞⰝⰋⰜⰀ!"

"✅ All OK! +1 point"

# %% [markdown]
# ## Задача X (1т.)
#
# Цензурирайте всички лоши думички в даден текст, заменяйки ги със звездички.
#
# * Лошите думички се дадени в списъка `BAD_WORDS`.
# * Върнете текста, като замените всички лоши думички със звездички (`"*"`) (толкова на брой, колкото символи има въпросната дума).
# * За простота не проверявайте за главни и малки букви, а ги заменяйте както са ви дадени.
# * Hint: за да създадете стринг с `n` на брой символа `"x"`, използвайте `n * "x"`.
# * Hint 2: ползвайте `str.replace`

# %%
BAD_WORDS = [
    "fuck",
    "shit",
    "bastard",
    "bitch",
    "whore",
    "damn",
]


def censored(text):
    pass # write your code here


# Tests:

assert censored("this line should not be censored at all") == "this line should not be censored at all"
assert censored("fuck this bitch") == "**** this *****"
assert censored("this task is complete bullshit") == "this task is complete bull****"
assert censored("") == ""

"✅ All OK! +1 points"

# %% [markdown]
# ## Задача X (1+1т.)
#
# Да се напише функция `should_be_banned(text, tags)`, която:
#
# * приема текст на пост в социална мрежа (тип `str`)
# * приема списък от таговете на поста (тип `list[str]`)
# * връща дали постът трябва да бъде "забранен" (тип `bool`)
#
# Постът трябва да бъде забранен, ако в текста или някой от таговете му се съдържа някоя от т. нар. забранени думи. Те са събрани в `BANNED_WORDS` списъка. Откриването на съвпадения трябва да е case-insensitive.

# %%
BANNED_WORDS = [
    "Tian'anmen",
    "天安门",
    "protest",
    "Winnie the Pooh",
    "democracy",
    "freedom",
    "human rights",
    "🕯️",
    "RIP",
    "Liu Xiaobo",
]


def should_be_banned(text, tags):
    pass # write your code here
    


# Tests:

assert should_be_banned("Xi Jinping is a good leader", ["leader"]) == False
assert should_be_banned("Will we ever know the truth regarding the Tian'anmen massacre?", ["protest", "天安门"]) == True
assert should_be_banned("I love 'Winnie the Pooh' movie!", ["pooh", "movie"]) == True, "it's enough if only the text violates the rules"
assert should_be_banned("MASSIVE PROTESTS", ["help"]) == True, "text check should be case-insensitive!"
assert should_be_banned("Heroes will not be forgotten...", ["rip"]) == True, "tags check should be case-insensitive!"
assert should_be_banned("Rest in Peace, brother", ["🕯️"]) == True
assert should_be_banned("", []) == False, "check your empty case"

print("✅ All OK! +1 point")

assert should_be_banned("Police violence in Hong Kong!..", ["hongkong", "protests"]) == True, "bonus if you check each tag for a substring match"

print("✅ Bonus achieved! +1 point (total of 2 from this task)")

# %% [markdown]
# ## Задача X (1т.)
#
# Направете стек:
#
# * в инициализатора си да приема неопределен брой аргументи - елементите на стека (първи-последен <-> отляво-надясно)
# * атрибут `top` - връща последния елемент от стека (`None` ако няма такъв)
# * метод `push(x)` - добавя `x` към края на стека
# * метод `pop()` - премахва последния елемент от стека
# * предефинирайте `__len__`

# %%
class Stack:
    pass # write your code here


# Tests:
assert Stack().top is None
assert Stack("a").top == "a"
assert Stack(1, 2, 3, 4, 5).top == 5
assert Stack(*list(range(1000))).top == 999

# pop
s = Stack("a", "b", "c", "d")
s.pop()
assert s.top == "c"
s.pop()
s.pop()
assert s.top == "a"
s.pop()
assert s.top is None

# push
s.push("X")
assert s.top == "X"
s.push("X")
s.push("X")
assert s.top == "X"

# len
assert len(s) == 3
s.pop(); s.pop(); s.pop()
assert len(s) == 0

"✅ All OK! +1 point"

# %% [markdown]
# ## Задача Y (1 т.)
#
# Създайте функция find_longest_word, която:
# * Приема 2 позиционни параметъра - списък и буква
# * Връща наредена двойка от най-късата и най-дългата дума в списъка с дадената буква

# %%
def find_longest_word(words, letter):
    pass

# Tests

assert find_longest_word(["abracadabra", "banana", "kugelschreiber", "ant", "almost", "thisshouldbeaverylongword"], "a") == ("ant", "abracadabra")
assert find_longest_word(["abracadabra", "banana", "kugelschreiber", "ant", "almost", "thisshouldbeaverylongword"], "b") == ("banana", "banana")

"✅ All OK! +1.0 points"

# %% [markdown]
# ## Задача Y (1 т.)
#
# Създайте функция student_grades, която:
# * Приема 1 позиционен параметър - списък, чиито елементи са от вида "X-Y", където X е името на ученика, а Y е оценка (цяло число между 2 и 6)
# * Връща dict, в който се пази информация за всеки ученик и средния му успех, който е закръглен до 2 знака след десетичната запетая
#     * За закръглянето използвайте round()

# %%
def student_grades(list_of_students_and_grades):
    pass

# Tests:

test_input = ["Ivan-6", "Maria-3", "Stasi-4", "Lili-5", "Petar-3",
            "Petar-4", "Maria-6", "Ivan-5", "Lili-4", "Stasi-3",
            "Lili-5", "Petar-4", "Ivan-6", "Stasi-5", "Maria-5"]
result = student_grades(test_input)
expected_result = {"Ivan":5.67, "Lili":4.67, "Maria":4.67, "Petar":3.67, "Stasi":4.00}
for key, value in expected_result.items():
    assert key in result
    assert result[key] == value
assert student_grades([]) == {}

"✅ All OK! +1.0 points"

# %% [markdown]
# ## Задача X (2т.)
#
# Направете клас `Account` (сметка), който има:
#
# * атрибут `id`: цяло число
# * атрибут `names`: низ от имената на притежателя на сметката
# * атрибут `iban`: низ с IBAN-а на сметката
# * атрибут `is_frozen`: булев флаг, показващ дали сметката е замразена или не
# * инициализатор, задаващ стойности за четирите атрибута, като:
#     * аргументът, съответстващ на `id`, може да бъде подаден като `str` или като `int`
#     * `is_frozen` по подразбиране да е `False`
# * getter-и, само ако прецените за необходимо (от setter-и няма нужда)
# * `__eq__`, сравняващо две сметки по `id` само
# * `__hash__`, връщащо хеша на `id`
# * метод `to_json_dict`, връщащ `dict` с четирите атрибута и техните съответстващи стойности
# * клас-метод `from_json_dict`, който създава инстанция на `Account` по даден `dict` във формата, описан горе
# * подходяща имплементация на  `__repr__`

# %%
class Account:
    pass # write your code here


# Tests:

assert Account(1, "Test Testerson", "BGTEST12300").id == 1
assert Account("1", "Test Testerson", "BGTEST12300").id == 1
assert Account(1, "Test Testerson", "BGTEST12300").names == "Test Testerson"
assert Account(1, "Test Testerson", "BGTEST12300").iban == "BGTEST12300"
assert Account(1, "Test Testerson", "BGTEST12300").is_frozen == False
assert Account(1, "Test Testerson", "BGTEST12300", is_frozen=True).is_frozen == True
assert Account(1, "Test Testerson", "BGTEST12300").is_frozen == False
assert Account(1, "Test Testerson", "BGTEST12300") == Account(1, "Test Testerson", "BGTEST12300")
assert Account(1, "Test Testerson", "BGTEST12300") == Account(1, "Test van der Teestricht", "BGTEST45600")
assert not Account(1, "Test Testerson", "BGTEST12300") == Account(2, "Test Testerson", "BGTEST12300")
assert not Account(1, "Test Testerson", "BGTEST12300") == Account(2, "Test van der Teestricht", "BGTEST45600")
assert len({Account(1, "1", "1"), Account(1, "2", "2")}) == 1
assert len({Account(1, "1", "1"), Account(2, "1", "1")}) == 2
assert Account(1, "A", "1").to_json_dict() == {"id": 1, "names": "A", "iban": "1", "is_frozen": False}
new_acc = Account.from_json_dict({"id": 1, "names": "A", "iban": "1", "is_frozen": True})
assert new_acc.id == 1
assert new_acc.names == "A"
assert new_acc.iban == "1"
assert new_acc.is_frozen == True
assert repr(Account(42, "AI", "XXX888")) == "Account(42, 'AI', 'XXX888', is_frozen=False)", "use ' for strings in __repr__"

"✅ All OK! +2 points"

# %% [markdown]
# ## Задача X (2т.)
#
# Да се дефинира клас `Version`, който моделира [числата на една софтуерна версия](https://en.wikipedia.org/wiki/Software_versioning#Semantic_versioning). Нека има следните свойства:
#
# * да може да се инициализира по два различни начина:
#     * чрез `str` във формат `{major}.{minor}.{patch}` (например `"1.0.2"`)
#     * чрез три `int`-a: `major`, `minor` и `patch` (например `1, 0, 2`)
# * read-only атрибут `major` (тип `int`)
# * read-only атрибут `minor` (тип `int`)
# * read-only атрибут `patch` (тип `int`)
# * метод `__str__`, който конвертира обекта в `str` в подходящ формат
# * метод `__repr__`, който връща репрезентация на обекта в подходящ формат
# * метод `__eq__`, който сравнява две версии в няколко различни случая:
#     1. ако другият операнд е от тип `Version`, сравнява ги с `==` по `major`, `minor` и `patch`
#     2. ако другият операнд е от тип `str`, то първо конвертира низa към `Version` и след това прилага горното правило
#     3. ако другият операнд е от друг тип, връща `False`
# * метод `__ne__`, който сравнява две версии по същия начин, но с `!=` вместо `==`
# * метод `__lt__`, който сравнява две версии по същия начин, но с `<` вместо `==`
# * метод `__gt__`, който сравнява две версии по същия начин, но с `>` вместо `==`
#
# Този клас хешируем ли е? Защо?

# %%
class Version:
    pass # write your code here


# Tests:

assert Version(1, 2, 3).major == 1
assert Version(1, 2, 3).minor == 2
assert Version(1, 2, 3).patch == 3
assert Version("1.2.3").major == 1
assert Version("1.2.3").minor == 2
assert Version("1.2.3").patch == 3
assert Version("10.2.304").major == 10
assert Version("10.2.304").minor == 2
assert Version("10.2.304").patch == 304
assert str(Version(1, 2, 3)) == "1.2.3"
assert repr(Version(1, 2, 3)) == "Version(1, 2, 3)"
assert Version(1, 2, 3) == Version(1, 2, 3)
assert Version(1, 2, 3) == "1.2.3"
assert Version(1, 2, 3) != Version(1, 2, 4)
assert Version(1, 2, 3) != "1.2.4"
assert Version(1, 2, 3) < Version(2, 0, 0)
assert Version(1, 2, 3) < "2.0.0"
assert Version(1, 2, 3) < Version(1, 3, 0)
assert Version(1, 2, 3) < "1.3.0"
assert Version(1, 2, 3) < Version(1, 2, 4)
assert Version(1, 2, 3) < "1.2.4"
assert Version("1.2.3") < Version("1.12.0")
assert Version("1.2.3") < "1.12.0"
assert Version(1, 2, 3) > Version(0, 9, 0)
assert Version(1, 2, 3) > "0.9.0"
assert Version(1, 2, 3) > Version(1, 1, 0)
assert Version(1, 2, 3) > "1.1.0"
assert Version(1, 2, 3) > Version(1, 2, 2)
assert Version(1, 2, 3) > "1.2.2"
assert Version("1.1.13") > Version("1.1.3")
assert Version("1.1.13") > "1.1.3"

"✅ All OK! +2 points"

# %% [markdown]
# ## Задача Y (2 т.)
#
# Създайте клас Student, който има:
# * атрибут faculty_number (цяло число)
# * атрибут first_name (низ)
# * атрибут last_name (низ)
# * атрибут major (низ)
# * атрибут is_extramural_student (т.е. дали учи задочно)
# * атрибут courses (списък)
# * инициализаторът приема и задава стойности на дадените атрибути.
#     * is_extramural_student ще приема стойност false, освен ако не се подаде друго
# * метод enroll(course), който приема име на курс и го добавя към списъка с курсове на студента
# * метод disenroll(course), който премахва подадения курс от списъка с курсове на студента, ако е бил записан.
# * метод `__str__`
# * метод `__repr__`
# * метод `__eq__` , който сравнява студентите според факултетните им номера (==)
# * метод `__ne__` , който сравнява студентите според факултетните им номера (!=)
# * метод `__lt__`, който сравнява студентите според факултетните им номера (<)
# * метод `__gt__` , който сравнява студентите според факултетните им номера (>)

# %%
class Student:
    pass

# Tests:

test_student = Student(89756, "Test", "Testov", "Computer Science")
assert test_student.faculty_number == 89756
assert test_student.first_name == "Test"
assert test_student.last_name == "Testov"
assert test_student.major == "Computer Science"
assert test_student.is_extramural_student == False
assert Student(89756, "Test", "Testov", "Computer Science", True).is_extramural_student == True
assert test_student.courses == []

test_student.enroll("Math")
test_student.enroll("Python")
assert len(test_student.courses) == 2
assert all(course in test_student.courses for course in ["Math", "Python"])
test_student.disenroll("C#")
assert len(test_student.courses) == 2
test_student.disenroll("Math")
assert len(test_student.courses) == 1
assert "Math" not in test_student.courses

assert Student(89756, "Test", "Testov", "Computer Science", True) == Student(89756, "Test", "Testov", "Computer Science", True)
assert Student(89756, "Test", "Testov", "Computer Science", True) != Student(98756, "Test", "Testov", "Computer Science", True)
assert Student(89756, "Test", "Testov", "Computer Science", True) < Student(98756, "Test", "Testov", "Computer Science", True)
assert Student(89756, "Test", "Testov", "Computer Science", True) > Student(78756, "Test", "Testov", "Computer Science", True)

"✅ All OK! +2.0 points"

# %% [markdown]
# ## Задача Y (2 т.)
#
# Създайте клас ElectronicDevice, който има:
# * атрибут serial_number (низ, смесица от латински букви и числа)
# * атрибут brand (низ)
# * атрибут model (низ)
# * атрибут year (число)
# * атрибут internal_memory (число)
# * инициализатор, който приема и задава стойности на дадените атрибути
# * метод show_device_info, който връща информация за устройството в следния формат: "You have electronic device {brand} {model} ({year}) with {internal_memory}GB memory"
# * метод show_storage_info, който връща съобщение "Your device has {internal_memory}GB"
# * метод `__str__`
# * метод `__repr__`
#
# Създайте клас Smartphone, който наследява класа ElectronicDevice. Нека има:
# * атрибут available_storage (число, първоначално равно на internal_memory)
# * атрибут main_camera_quality (число)
# * атрибут installed_apps (списък, по подразбиране е празен)
# * инициализатор, който приема и задава стойности на дадените атрибути
# * метод show_device_info, който връща информация за устройството в следния формат: "You have smartphone {brand} {model} ({year}) with {internal_memory}GB memory and {main_camera_quality}MP camera"
# * метод show_storage_info, който връща съобщение "Your smartphone has {available_storage}GB available storage out of {internal_memory}GB"
# * метод install_app(app_name, space_needed), който:
#     * Ако е възможно, добавя приложението към списъка с приложения и извежда съобщение "You successfully installed {app_name}".
#     * Ако не е възможно, връща съобщение "Seems like you don't have enough space. Available storage space: {available_storage}GB"
# * метод take_photo(), който връща съобщение "You just took a photo with {brand} {model}'s {main_camera_quality}MP camera"
# * метод `__str__`
# * метод `__repr__`
#
# Създайте клас Laptop, който наследява класа ElectronicDevice. Нека има:
# * атрибут processor (низ)
# * атрибут processor_version (низ)
# * инициализатор, който приема и задава стойности на дадените атрибути
# * метод show_device_info, който връща информация за устройството в следния формат: "You have laptop {brand} {model} ({year}) with {internal_memory}GB memory and {processor} {processor_version} processor"
# * метод show_storage_info, който връща съобщение "Your laptop has {internal_memory}GB"
# * метод connect_device(device_name), който връща следното съобщение: "You just connected {device_name} to {brand} {model}"
# * метод `__str__`
# * метод `__repr__`

# %%
class ElectronicDevice:
    pass

class Smartphone:
    pass

class Laptop:
    pass

# Tests:

# ElectronicDevice tests
test_electronic_device = ElectronicDevice("8vef15c6", "TestBrand", "TestModel", 2023, 128)
assert test_electronic_device.serial_number == "8vef15c6"
assert test_electronic_device.brand == "TestBrand"
assert test_electronic_device.model == "TestModel"
assert test_electronic_device.year == 2023
assert test_electronic_device.internal_memory == 128
assert test_electronic_device.show_device_info() == "You have electronic device TestBrand TestModel (2023) with 128GB memory"
assert test_electronic_device.show_storage_info() == "Your device has 128GB"

# Smarthphone tests
assert issubclass(Smartphone, ElectronicDevice)
test_smartphone = Smartphone("9pol23k7", "TestBrand2", "TestModel2", 2021, 256, main_camera_quality=13)
assert test_smartphone.serial_number == "9pol23k7"
assert test_smartphone.brand == "TestBrand2"
assert test_smartphone.model == "TestModel2"
assert test_smartphone.year == 2021
assert test_smartphone.internal_memory == 256
assert test_smartphone.available_storage == 256
assert test_smartphone.main_camera_quality == 13
assert test_smartphone.installed_apps == []
assert test_smartphone.show_device_info() == "You have smartphone TestBrand2 TestModel2 (2021) with 256GB memory and 13MP camera"
res1 =  test_smartphone.install_app("TestApp", 56)
assert res1 == "You successfully installed TestApp"
assert len(test_smartphone.installed_apps) == 1
assert "TestApp" in test_smartphone.installed_apps
assert test_smartphone.show_storage_info() == "Your smartphone has 200GB available storage out of 256GB"
res2 = test_smartphone.install_app("TestApp2", 201)
assert res2 == "Seems like you don't have enough space. Available storage space: 200GB"
assert len(test_smartphone.installed_apps) == 1
assert "TestApp2" not in test_smartphone.installed_apps 
assert test_smartphone.take_photo() == "You just took a photo with TestBrand2 TestModel2's 13MP camera" 

# Laptop tests
assert issubclass(Laptop, ElectronicDevice)
test_laptop = Laptop("7yeu14t3", "TestBrand3", "TestModel3", 2013, 512, "TestProcessor", "v5.2.1.13")
assert test_laptop.serial_number == "7yeu14t3"
assert test_laptop.brand == "TestBrand3"
assert test_laptop.model == "TestModel3"
assert test_laptop.year == 2013
assert test_laptop.internal_memory == 512
assert test_laptop.processor == "TestProcessor"
assert test_laptop.processor_version == "v5.2.1.13"
assert test_laptop.show_device_info() == "You have laptop TestBrand3 TestModel3 (2013) with 512GB memory and TestProcessor v5.2.1.13 processor"
assert test_laptop.show_storage_info() == "Your laptop has 512GB"
assert test_laptop.connect_device("TestConnectedDevice") == "You just connected TestConnectedDevice to TestBrand3 TestModel3"

"✅ All OK! +2.0 points"
